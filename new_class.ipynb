# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree,out_file=dot_data,
               filled=True,rounded=True,
               special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import numpy as np

# %%
C = np.array([[1,2,3],[2,3,4]])

# %%
D = np.array([[1,2,3,4],[2,3,4,5],[3,4,5,6]])

# %%
C@D
# Out:
# array([[14, 20, 26, 32],
#        [20, 29, 38, 47]])

# %%
C*C
# Out:
# array([[ 1,  4,  9],
#        [ 4,  9, 16]])

# %%
#np.dot(a,b) = a,b 矩阵相乘

# %% [markdown]
# import tensorflow as tf

# %% [markdown]
# # Markdown使用：
# #   标题
# ##
# ###
# ###
#
# **黑体**
# *斜体*
#
# >引用一段话
#
# * 列观点，得加空格
# * 得要英文，不带序号
#     * **重点子序号观点**
#
#
# 1. 这次带个序号
# 1. 直接输数字加点，并且和前面的数字无关
# 2. 而且得要有个空格
#
# Latex 一些数学符号
# $e^{i\pi}+1 = 0$
# $\sum$
# 等等
#
# # 插入图片
# * 第一种
# ![此处无所谓,是标题](此处放地址，网络本地皆可)
# ![image.png](attachment:image.png)测试结果为爱奇艺万能播放器打开后右键复制，建议使用jpg，或本地的放在jupyter notebook目录下
# * 第二种
# <img src='attachment:image.png',width=500,height= 500>
#
# # 插入表格
# |  第一栏 |  第二栏|第三栏|
# | :----------|--------|-------:|
# | 阿萨德|阿萨德|奥术大师|冒号是左右对齐

# %%
#>conda create -n 文件名 Python=几点几
#>activate 
#>deactivate
#>pip install 工具名
